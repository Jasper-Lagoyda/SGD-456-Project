# %%
import numpy as np
import matplotlib.pyplot as plt

# Rosenbrock function
def rosenbrock(x, y):
    return (1 - x)**2 + 100 * (y - x**2)**2

# Gradient of Rosenbrock function
def rosenbrock_gradient(x, y):
    dx = -2 * (1 - x) - 400 * x * (y - x**2)
    dy = 200 * (y - x**2)
    return np.array([dx, dy])

# Batch Gradient Descent
def batch_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        gradient = gradient_fn(x[0], x[1])
        x = x - lr * gradient
        trajectory.append(x)
    return np.array(trajectory)

# Stochastic Gradient Descent
def stochastic_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        random_gradient = gradient_fn(*x* np.random.random(2))
        x = x - lr * random_gradient
        trajectory.append(x)
    return np.array(trajectory)

# Common parameters
learning_rate = 0.001
max_iterations = 10000

# Generate contour plot
x = np.linspace(-2.0, 2.0, 100)
y = np.linspace(-1.0, 3.0, 100)
X, Y = np.meshgrid(x, y)
Z = rosenbrock(X, Y)

# Calculate minimum point of the Rosenbrock function
min_point = np.array([1, 1])  # Minimum point of the function

# Batch Gradient Descent
batch_traj = batch_gradient_descent(rosenbrock_gradient, lr=learning_rate, num_iterations=max_iterations)

# Stochastic Gradient Descent
stochastic_traj = stochastic_gradient_descent(rosenbrock_gradient, lr=learning_rate, num_iterations=max_iterations)

plt.figure(figsize=(8, 6))

plt.subplot(1, 2, 1)
plt.contour(X, Y, Z, levels=np.logspace(-1, 3, 20))
batch_x_vals = batch_traj[:, 0]
batch_y_vals = batch_traj[:, 1]
plt.scatter(batch_x_vals, batch_y_vals, c='red', label='Batch GD')
plt.plot(batch_x_vals, batch_y_vals, linestyle='-', color='red')  # Add lines
plt.scatter(min_point[0], min_point[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Batch Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-2, 2)  # Adjust the X-axis limits
plt.ylim(-1, 3)  # Adjust the Y-axis limits

plt.subplot(1, 2, 2)
plt.contour(X, Y, Z, levels=np.logspace(-1, 3, 20))
stochastic_x_vals = stochastic_traj[:, 0]
stochastic_y_vals = stochastic_traj[:, 1]
plt.scatter(stochastic_x_vals, stochastic_y_vals, c='blue', label='SGD')
plt.plot(stochastic_x_vals, stochastic_y_vals, linestyle='-', color='blue')  # Add lines
plt.scatter(min_point[0], min_point[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Stochastic Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-2, 2)  # Adjust the X-axis limits
plt.ylim(-1, 3)  # Adjust the Y-axis limits

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Sphere function
def sphere(x, y):
    return x**2 + y**2

# Gradient of Sphere function
def sphere_gradient(x, y):
    return np.array([2 * x, 2 * y])

# Batch Gradient Descent
def batch_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        gradient = gradient_fn(x[0], x[1])
        x = x - lr * gradient
        trajectory.append(x)
    return np.array(trajectory)

# Stochastic Gradient Descent
def stochastic_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        random_gradient = gradient_fn(*x* np.random.random(2))
        x = x - lr * random_gradient
        trajectory.append(x)
    return np.array(trajectory)

# Common parameters
learning_rate = 0.001
max_iterations = 10000

# Generate contour plot
x = np.linspace(-2.0, 2.0, 100)
y = np.linspace(-1.0, 3.0, 100)
X, Y = np.meshgrid(x, y)
Z = rosenbrock(X, Y)

# Calculate minimum point of the Rosenbrock function
min_point = np.array([1, 1])  # Minimum point of the function

# Generate contour plot for Sphere function
x_sphere = np.linspace(-2.0, 2.0, 100)
y_sphere = np.linspace(-2.0, 2.0, 100)
X_sphere, Y_sphere = np.meshgrid(x_sphere, y_sphere)
Z_sphere = sphere(X_sphere, Y_sphere)

# Calculate minimum point of the Sphere function
min_point_sphere = np.array([0, 0])  # Minimum point of the function

# Batch Gradient Descent for Sphere function
batch_traj_sphere = batch_gradient_descent(sphere_gradient, lr=learning_rate, num_iterations=max_iterations)

# Stochastic Gradient Descent for Sphere function
stochastic_traj_sphere = stochastic_gradient_descent(sphere_gradient, lr=learning_rate, num_iterations=max_iterations)

# Plotting Batch and Stochastic Gradient Descent for Sphere function
plt.figure(figsize=(8, 6))

plt.subplot(1, 2, 1)
plt.contour(X_sphere, Y_sphere, Z_sphere, levels=np.linspace(0, 8, 20))
batch_x_vals_sphere = batch_traj_sphere[:, 0]
batch_y_vals_sphere = batch_traj_sphere[:, 1]
plt.scatter(batch_x_vals_sphere, batch_y_vals_sphere, c='red', label='Batch GD')
plt.plot(batch_x_vals_sphere, batch_y_vals_sphere, linestyle='-', color='red')  # Add lines
plt.scatter(min_point_sphere[0], min_point_sphere[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Batch Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-2, 2)  # Adjust the X-axis limits
plt.ylim(-2, 2)  # Adjust the Y-axis limits

plt.subplot(1, 2, 2)
plt.contour(X_sphere, Y_sphere, Z_sphere, levels=np.linspace(0, 8, 20))
stochastic_x_vals_sphere = stochastic_traj_sphere[:, 0]
stochastic_y_vals_sphere = stochastic_traj_sphere[:, 1]
plt.scatter(stochastic_x_vals_sphere, stochastic_y_vals_sphere, c='blue', label='SGD')
plt.plot(stochastic_x_vals_sphere, stochastic_y_vals_sphere, linestyle='-', color='blue')  # Add lines
plt.scatter(min_point_sphere[0], min_point_sphere[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Stochastic Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-2, 2)  # Adjust the X-axis limits
plt.ylim(-2, 2)  # Adjust the Y-axis limits

plt.tight_layout()
plt.show()

# %%
# Ackley function
def ackley(x, y):
    a = 20
    b = 0.2
    c = 2 * np.pi
    term1 = -a * np.exp(-b * np.sqrt(0.5 * (x**2 + y**2)))
    term2 = -np.exp(0.5 * (np.cos(c * x) + np.cos(c * y)))
    return term1 + term2 + a + np.exp(1)

# Gradient of Ackley function (Approximation for visualization)
def ackley_gradient(x, y):
    dx = -x / np.sqrt(x**2 + y**2) * np.exp(-0.2 * np.sqrt(x**2 + y**2)) - 2 * np.pi * np.sin(2 * np.pi * x) * np.exp(0.5 * (np.cos(2 * np.pi * x) + np.cos(2 * np.pi * y)))
    dy = -y / np.sqrt(x**2 + y**2) * np.exp(-0.2 * np.sqrt(x**2 + y**2)) - 2 * np.pi * np.sin(2 * np.pi * y) * np.exp(0.5 * (np.cos(2 * np.pi * x) + np.cos(2 * np.pi * y)))
    return np.array([dx, dy])

# Batch Gradient Descent
def batch_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        gradient = gradient_fn(x[0], x[1])
        x = x + lr * gradient
        trajectory.append(x)
    return np.array(trajectory)

# Stochastic Gradient Descent
def stochastic_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        random_gradient = gradient_fn(*x* np.random.random(2))
        x = x + lr * random_gradient
        trajectory.append(x)
    return np.array(trajectory)

# Common parameters
learning_rate = 0.001
max_iterations = 10000

# Generate contour plot
x = np.linspace(-2.0, 2.0, 100)
y = np.linspace(-1.0, 3.0, 100)
X, Y = np.meshgrid(x, y)
Z = rosenbrock(X, Y)

# Calculate minimum point of the Rosenbrock function
min_point = np.array([1, 1])  # Minimum point of the function

# Generate contour plot for Ackley function
x_ackley = np.linspace(-5, 5, 100)
y_ackley = np.linspace(-5, 5, 100)
X_ackley, Y_ackley = np.meshgrid(x_ackley, y_ackley)
Z_ackley = ackley(X_ackley, Y_ackley)

# Calculate minimum point of the Ackley function
min_point_ackley = np.array([0, 0])  # Minimum point of the function

# Batch Gradient Descent for Ackley function
batch_traj_ackley = batch_gradient_descent(ackley_gradient, lr=learning_rate, num_iterations=max_iterations)

# Stochastic Gradient Descent for Ackley function
stochastic_traj_ackley = stochastic_gradient_descent(ackley_gradient, lr=learning_rate, num_iterations=max_iterations)

# Plotting Batch and Stochastic Gradient Descent for Ackley function
plt.figure(figsize=(8, 6))

plt.subplot(1, 2, 1)
plt.contour(X_ackley, Y_ackley, Z_ackley, levels=np.linspace(0, 20, 50))
batch_x_vals_ackley = batch_traj_ackley[:, 0]
batch_y_vals_ackley = batch_traj_ackley[:, 1]
plt.scatter(batch_x_vals_ackley, batch_y_vals_ackley, c='red', label='Batch GD')
plt.plot(batch_x_vals_ackley, batch_y_vals_ackley, linestyle='-', color='red')  # Add lines
plt.scatter(min_point_ackley[0], min_point_ackley[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Batch Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5, 5)  # Adjust the X-axis limits
plt.ylim(-5, 5)  # Adjust the Y-axis limits

plt.subplot(1, 2, 2)
plt.contour(X_ackley, Y_ackley, Z_ackley, levels=np.linspace(0, 20, 50))
stochastic_x_vals_ackley = stochastic_traj_ackley[:, 0]
stochastic_y_vals_ackley = stochastic_traj_ackley[:, 1]
plt.scatter(stochastic_x_vals_ackley, stochastic_y_vals_ackley, c='blue', label='SGD')
plt.plot(stochastic_x_vals_ackley, stochastic_y_vals_ackley, linestyle='-', color='blue')  # Add lines
plt.scatter(min_point_ackley[0], min_point_ackley[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Stochastic Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5, 5)  # Adjust the X-axis limits
plt.ylim(-5, 5)  # Adjust the Y-axis limits

plt.tight_layout()
plt.show()

# %%
# Rastrigin function
def rastrigin(x, y):
    A = 10
    return 2 * A + x**2 - A * np.cos(2 * np.pi * x) + y**2 - A * np.cos(2 * np.pi * y)

# Gradient of Rastrigin function (Approximation for visualization)
def rastrigin_gradient(x, y):
    dx = 2 * x + 2 * np.pi * 10 * np.sin(2 * np.pi * x)
    dy = 2 * y + 2 * np.pi * 10 * np.sin(2 * np.pi * y)
    return np.array([dx, dy])

# Batch Gradient Descent
def batch_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        gradient = gradient_fn(x[0], x[1])
        x = x - lr * gradient
        trajectory.append(x)
    return np.array(trajectory)

# Stochastic Gradient Descent
def stochastic_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        random_gradient = gradient_fn(*x* np.random.random(2))
        x = x - lr * random_gradient
        trajectory.append(x)
    return np.array(trajectory)

# Common parameters
learning_rate = 0.001
max_iterations = 10000

# Generate contour plot for Rastrigin function
x_rastrigin = np.linspace(-5.12, 5.12, 100)
y_rastrigin = np.linspace(-5.12, 5.12, 100)
X_rastrigin, Y_rastrigin = np.meshgrid(x_rastrigin, y_rastrigin)
Z_rastrigin = rastrigin(X_rastrigin, Y_rastrigin)

# Calculate minimum point of the Rastrigin function
min_point_rastrigin = np.array([0, 0])  # Minimum point of the function

# Batch Gradient Descent for Rastrigin function
batch_traj_rastrigin = batch_gradient_descent(rastrigin_gradient, lr=learning_rate, num_iterations=max_iterations)

# Stochastic Gradient Descent for Rastrigin function
stochastic_traj_rastrigin = stochastic_gradient_descent(rastrigin_gradient, lr=learning_rate, num_iterations=max_iterations)

# Plotting Batch and Stochastic Gradient Descent for Rastrigin function
plt.figure(figsize=(8, 6))

plt.subplot(1, 2, 1)
plt.contour(X_rastrigin, Y_rastrigin, Z_rastrigin, levels=np.linspace(0, 200, 50))
batch_x_vals_rastrigin = batch_traj_rastrigin[:, 0]
batch_y_vals_rastrigin = batch_traj_rastrigin[:, 1]
plt.scatter(batch_x_vals_rastrigin, batch_y_vals_rastrigin, c='red', label='Batch GD')
plt.plot(batch_x_vals_rastrigin, batch_y_vals_rastrigin, linestyle='-', color='red')  # Add lines
plt.scatter(min_point_rastrigin[0], min_point_rastrigin[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Batch Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5.12, 5.12)  # Adjust the X-axis limits
plt.ylim(-5.12, 5.12)  # Adjust the Y-axis limits

plt.subplot(1, 2, 2)
plt.contour(X_rastrigin, Y_rastrigin, Z_rastrigin, levels=np.linspace(0, 200, 50))
stochastic_x_vals_rastrigin = stochastic_traj_rastrigin[:, 0]
stochastic_y_vals_rastrigin = stochastic_traj_rastrigin[:, 1]
plt.scatter(stochastic_x_vals_rastrigin, stochastic_y_vals_rastrigin, c='blue', label='SGD')
plt.plot(stochastic_x_vals_rastrigin, stochastic_y_vals_rastrigin, linestyle='-', color='blue')  # Add lines
plt.scatter(min_point_rastrigin[0], min_point_rastrigin[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title('Stochastic Gradient Descent')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5.12, 5.12)  # Adjust the X-axis limits
plt.ylim(-5.12, 5.12)  # Adjust the Y-axis limits

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Himmelblau's function
def himmelblau(x, y):
    return (x**2 + y - 11)**2 + (x + y**2 - 7)**2

# Gradient of Himmelblau's function (using numpy functions)
def himmelblau_gradient(x, y):
    dx = 2 * (2 * x * (x**2 + y - 11) + x + y**2 - 7)
    dy = 2 * (x**2 + 2 * y * (x + y**2 - 7) + y - 11)
    return np.array([dx, dy])

# Common parameters
learning_rate = 0.001
max_iterations = 100000

# Generate contour plot for Himmelblau's function
x_himmelblau = np.linspace(-5, 5, 100)
y_himmelblau = np.linspace(-5, 5, 100)
X_himmelblau, Y_himmelblau = np.meshgrid(x_himmelblau, y_himmelblau)
Z_himmelblau = himmelblau(X_himmelblau, Y_himmelblau)

# Calculate minimum point of Himmelblau's function
min_point_himmelblau = np.array([3, 2])  # Minimum point of the function

# Batch Gradient Descent for Himmelblau's function
def batch_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        gradient = gradient_fn(*x)
        x = x - lr * gradient
        trajectory.append(x)
    return np.array(trajectory)

# Stochastic Gradient Descent for Himmelblau's function
def stochastic_gradient_descent(gradient_fn, lr, num_iterations):
    x = np.array([-2, 2])  # Initial point
    trajectory = [x]
    for i in range(num_iterations):
        random_gradient = gradient_fn(*x* np.random.random(2)) 
        x = x  - lr * random_gradient
        trajectory.append(x)
    return np.array(trajectory)

# Batch Gradient Descent for Himmelblau's function
batch_traj_himmelblau = batch_gradient_descent(himmelblau_gradient, lr=learning_rate, num_iterations=max_iterations)

# Stochastic Gradient Descent for Himmelblau's function
stochastic_traj_himmelblau = stochastic_gradient_descent(himmelblau_gradient, lr=learning_rate, num_iterations=max_iterations)

# Plotting Batch and Stochastic Gradient Descent for Himmelblau's function
plt.figure(figsize=(8, 6))

plt.subplot(1, 2, 1)
plt.contour(X_himmelblau, Y_himmelblau, Z_himmelblau, levels=np.logspace(0, 5, 50))
batch_x_vals_himmelblau = batch_traj_himmelblau[:, 0]
batch_y_vals_himmelblau = batch_traj_himmelblau[:, 1]
plt.scatter(batch_x_vals_himmelblau, batch_y_vals_himmelblau, c='red', label='Batch GD')
plt.plot(batch_x_vals_himmelblau, batch_y_vals_himmelblau, linestyle='-', color='red')  # Add lines
plt.scatter(min_point_himmelblau[0], min_point_himmelblau[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title("Batch Gradient Descent")
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5, 5)  # Adjust the X-axis limits
plt.ylim(-5, 5)  # Adjust the Y-axis limits

plt.subplot(1, 2, 2)
plt.contour(X_himmelblau, Y_himmelblau, Z_himmelblau, levels=np.logspace(0, 5, 50))
stochastic_x_vals_himmelblau = stochastic_traj_himmelblau[:, 0]
stochastic_y_vals_himmelblau = stochastic_traj_himmelblau[:, 1]
plt.scatter(stochastic_x_vals_himmelblau, stochastic_y_vals_himmelblau, c='blue', label='SGD')
plt.plot(stochastic_x_vals_himmelblau, stochastic_y_vals_himmelblau, linestyle='-', color='blue')  # Add lines
plt.scatter(min_point_himmelblau[0], min_point_himmelblau[1], c='green', label='Minimum', marker='o')  # Add minimum point
plt.title("Stochastic Gradient Descent")
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.xlim(-5, 5)  # Adjust the X-axis limits
plt.ylim(-5, 5)  # Adjust the Y-axis limits

plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 9
#       3 import time
#       5 # Function definitions for Rosenbrock, Sphere, Ackley, Rastrigin, Himmelblau, gradients, BGD, SGD...
#       7 functions = {
#       8     'Rosenbrock': rosenbrock,
# ----> 9     'Sphere': sphere,
#      10     'Ackley': ackley,
#      11     'Rastrigin': rastrigin,
#      12     'Himmelblau': himmelblau
#      13 }
#      15 gradient_functions = {
#      16     'Rosenbrock': rosenbrock_gradient,
#      17     'Sphere': sphere_gradient,
#    (...)
#      20     'Himmelblau': himmelblau_gradient
#      21 }
#      23 # Common parameters
#
# NameError: name 'sphere' is not defined
